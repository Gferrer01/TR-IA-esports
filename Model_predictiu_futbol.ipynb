# %% [markdown]
# <a href="https://colab.research.google.com/github/Gferrer01/TR-IA-esports/blob/main/Model_predictiu_futbol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inserció i avaluació de dades

# %%
import pandas as pd

# %%
partits=pd.read_csv("spain-la-liga-matches-2022-to-2023-stats.csv", index_col=0) #inserim l'arxiu
partits.head() #mostrem les primeres 5 línies
# Out:
#                         date_GMT    status  attendance   home_team_name  \
# timestamp
# 1660330800  Aug 12 2022 - 7:00pm  complete         NaN       CA Osasuna
# 1660402800  Aug 13 2022 - 3:00pm  complete     18859.0    Celta de Vigo
# 1660410000  Aug 13 2022 - 5:00pm  complete         NaN  Real Valladolid
# 1660417200  Aug 13 2022 - 7:00pm  complete         NaN     FC Barcelona
# 1660491000  Aug 14 2022 - 3:30pm  complete     16570.0            Cádiz
#
#             away_team_name                             referee  Game Week  \
# timestamp
# 1660330800      Sevilla FC             Carlos Del Cerro Grande          1
# 1660402800    RCD Espanyol            Miguel Ángel Ortiz Arias          1
# 1660410000      Villarreal                  Mario Melero López          1
# 1660417200  Rayo Vallecano  Alejandro José Hernández Hernández          1
# 1660491000   Real Sociedad       Isidro Díaz de Mera Escuderos          1
#
#             Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_ppg  ...  \
# timestamp                                                         ...
# 1660330800                   0.0                   0.0      1.79  ...
# 1660402800                   0.0                   0.0      1.42  ...
# 1660410000                   0.0                   0.0      1.47  ...
# 1660417200                   0.0                   0.0      2.53  ...
# 1660491000                   0.0                   0.0      1.42  ...
#
#             odds_ft_home_team_win  odds_ft_draw  odds_ft_away_team_win  \
# timestamp
# 1660330800                   3.27          3.08                   2.13
# 1660402800                   1.88          3.70                   4.04
# 1660410000                   3.80          3.65                   1.95
# 1660417200                   1.20          7.00                  13.55
# 1660491000                   3.15          3.28                   2.54
#
#             odds_ft_over15  odds_ft_over25  odds_ft_over35  odds_ft_over45  \
# timestamp
# 1660330800            1.47            2.30            4.75           10.00
# 1660402800            1.33            1.98            3.60            7.00
# 1660410000            1.32            1.91            3.50            6.50
# 1660417200            1.15            1.46            2.28            3.75
# 1660491000            1.45            2.30            4.50            9.50
#
#            odds_btts_yes odds_btts_no  \
# timestamp
# 1660330800          2.00         1.75
# 1660402800          1.80         1.95
# 1660410000          1.75         2.00
# 1660417200          2.10         1.67
# 1660491000          2.00         1.75
#
#                                             stadium_name
# timestamp
# 1660330800          Estadio El Sadar (Pamplona (Iruñea))
# 1660402800                        Abanca-Balaídos (Vigo)
# 1660410000  Estadio Municipal José Zorrilla (Valladolid)
# 1660417200                  Spotify Camp Nou (Barcelona)
# 1660491000              Estadio Nuevo Mirandilla (Cádiz)
#
# [5 rows x 65 columns]

# %%
partits.shape #380 partits, per tant el data set és complet
# Out:
# (380, 65)

# %%
partits.dtypes #observem els tipus de cada paràmetre, per a saber si hem de fer alguns canvis
# Out:
# date_GMT           object
# status             object
# attendance        float64
# home_team_name     object
# away_team_name     object
#                    ...
# odds_ft_over35    float64
# odds_ft_over45    float64
# odds_btts_yes     float64
# odds_btts_no      float64
# stadium_name       object
# Length: 65, dtype: object

# %% [markdown]
# # Tractament de dades per a fer el model

# %%
partits["date_GMT"]=pd.to_datetime(partits["date_GMT"]) #convertim el string de la data a format data de pandas
partits.dtypes
# Out:
# <ipython-input-5-78b194ab376e>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   partits["date_GMT"]=pd.to_datetime(partits["date_GMT"]) #convertim el string de la data a format data de pandas
# date_GMT          datetime64[ns]
# status                    object
# attendance               float64
# home_team_name            object
# away_team_name            object
#                        ...
# odds_ft_over35           float64
# odds_ft_over45           float64
# odds_btts_yes            float64
# odds_btts_no             float64
# stadium_name              object
# Length: 65, dtype: object

# %%
del partits["status"]
del partits["attendance"]
del partits["stadium_name"] #eliminem paràmetres innecessaris

# %%
partits.shape
partits.head()
# Out:
#                       date_GMT   home_team_name  away_team_name  \
# timestamp
# 1660330800 2022-08-12 19:00:00       CA Osasuna      Sevilla FC
# 1660402800 2022-08-13 15:00:00    Celta de Vigo    RCD Espanyol
# 1660410000 2022-08-13 17:00:00  Real Valladolid      Villarreal
# 1660417200 2022-08-13 19:00:00     FC Barcelona  Rayo Vallecano
# 1660491000 2022-08-14 15:30:00            Cádiz   Real Sociedad
#
#                                        referee  Game Week  \
# timestamp
# 1660330800             Carlos Del Cerro Grande          1
# 1660402800            Miguel Ángel Ortiz Arias          1
# 1660410000                  Mario Melero López          1
# 1660417200  Alejandro José Hernández Hernández          1
# 1660491000       Isidro Díaz de Mera Escuderos          1
#
#             Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_ppg  away_ppg  \
# timestamp
# 1660330800                   0.0                   0.0      1.79      1.21
# 1660402800                   0.0                   0.0      1.42      0.95
# 1660410000                   0.0                   0.0      1.47      1.32
# 1660417200                   0.0                   0.0      2.53      0.89
# 1660491000                   0.0                   0.0      1.42      1.74
#
#             home_team_goal_count  ...  average_cards_per_match_pre_match  \
# timestamp                         ...
# 1660330800                     2  ...                                0.0
# 1660402800                     2  ...                                0.0
# 1660410000                     0  ...                                0.0
# 1660417200                     0  ...                                0.0
# 1660491000                     0  ...                                0.0
#
#             odds_ft_home_team_win  odds_ft_draw  odds_ft_away_team_win  \
# timestamp
# 1660330800                   3.27          3.08                   2.13
# 1660402800                   1.88          3.70                   4.04
# 1660410000                   3.80          3.65                   1.95
# 1660417200                   1.20          7.00                  13.55
# 1660491000                   3.15          3.28                   2.54
#
#             odds_ft_over15 odds_ft_over25 odds_ft_over35  odds_ft_over45  \
# timestamp
# 1660330800            1.47           2.30           4.75           10.00
# 1660402800            1.33           1.98           3.60            7.00
# 1660410000            1.32           1.91           3.50            6.50
# 1660417200            1.15           1.46           2.28            3.75
# 1660491000            1.45           2.30           4.50            9.50
#
#             odds_btts_yes  odds_btts_no
# timestamp
# 1660330800           2.00          1.75
# 1660402800           1.80          1.95
# 1660410000           1.75          2.00
# 1660417200           2.10          1.67
# 1660491000           2.00          1.75
#
# [5 rows x 62 columns]

# %%
partits["home_team_code"] = partits["home_team_name"].astype("category").cat.codes
partits["away_team_code"]=partits["away_team_name"].astype("category").cat.codes
partits["referee_code"]=partits["referee"].astype("category").cat.codes
partits["day_code"] = partits["date_GMT"].dt.dayofweek
partits["hour"] = partits["date_GMT"].dt.hour
#convertim els equips, àrbitres, dies i hores en format numèric
partits.head()
# Out:
#                       date_GMT   home_team_name  away_team_name  \
# timestamp
# 1660330800 2022-08-12 19:00:00       CA Osasuna      Sevilla FC
# 1660402800 2022-08-13 15:00:00    Celta de Vigo    RCD Espanyol
# 1660410000 2022-08-13 17:00:00  Real Valladolid      Villarreal
# 1660417200 2022-08-13 19:00:00     FC Barcelona  Rayo Vallecano
# 1660491000 2022-08-14 15:30:00            Cádiz   Real Sociedad
#
#                                        referee  Game Week  \
# timestamp
# 1660330800             Carlos Del Cerro Grande          1
# 1660402800            Miguel Ángel Ortiz Arias          1
# 1660410000                  Mario Melero López          1
# 1660417200  Alejandro José Hernández Hernández          1
# 1660491000       Isidro Díaz de Mera Escuderos          1
#
#             Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_ppg  away_ppg  \
# timestamp
# 1660330800                   0.0                   0.0      1.79      1.21
# 1660402800                   0.0                   0.0      1.42      0.95
# 1660410000                   0.0                   0.0      1.47      1.32
# 1660417200                   0.0                   0.0      2.53      0.89
# 1660491000                   0.0                   0.0      1.42      1.74
#
#             home_team_goal_count  ...  odds_ft_over25  odds_ft_over35  \
# timestamp                         ...
# 1660330800                     2  ...            2.30            4.75
# 1660402800                     2  ...            1.98            3.60
# 1660410000                     0  ...            1.91            3.50
# 1660417200                     0  ...            1.46            2.28
# 1660491000                     0  ...            2.30            4.50
#
#             odds_ft_over45  odds_btts_yes  odds_btts_no home_team_code  \
# timestamp
# 1660330800           10.00           2.00          1.75              3
# 1660402800            7.00           1.80          1.95              4
# 1660410000            6.50           1.75          2.00             16
# 1660417200            3.75           2.10          1.67              7
# 1660491000            9.50           2.00          1.75              5
#
#            away_team_code  referee_code  day_code  hour
# timestamp
# 1660330800             17             3         4    19
# 1660402800             10            16         5    15
# 1660410000             19            15         5    17
# 1660417200             12             0         5    19
# 1660491000             15             6         6    15
#
# [5 rows x 67 columns]

# %% [markdown]
# #Creació del model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#sorted(partits.select_dtypes(include=["int64", "float64"]))

# %%
rf_golsafavor = RandomForestClassifier(n_estimators=100, min_samples_split=15, random_state=1)
rf_golsencontra = RandomForestClassifier(n_estimators=100, min_samples_split=15, random_state=1)

# %%
train=partits[partits["Game Week"]<20]
test=partits[partits["Game Week"]>19]
predictors=["home_team_code", "away_team_code", "referee_code", "day_code", "hour"]
#predictors=sorted(partits.select_dtypes(include=["int64", "float64"]))

# %%
rf_golsafavor.fit(train[predictors], train["home_team_goal_count"])
rf_golsencontra.fit(train[predictors], train["away_team_goal_count"])
# Out:
# RandomForestClassifier(min_samples_split=15, random_state=1)

# %%
predic_golsafavor=rf_golsafavor.predict(test[predictors])
predic_golsencontra=rf_golsencontra.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
encert_golsafavor = accuracy_score(test["home_team_goal_count"], predic_golsafavor, normalize=True)
encert_golsencontra= accuracy_score(test["away_team_goal_count"], predic_golsencontra, normalize=True)
print(encert_golsafavor)
print(encert_golsencontra)
# Out:
# 0.3
# 0.3631578947368421

# %%
len(predic_golsencontra)
# Out:
# 190
